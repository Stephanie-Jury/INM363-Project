# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
epochs = "20"
learning_rate = "0.01"
dataset = 'IMDB'
input_length = "28"
embedding = 'word2vec_300'
dim_red = "PCA"
optim = "adam"

# %%
path = '/Users/steffjury/PycharmProjects/INM363-Project-REFACTOR/'+ epochs +'_epochs/model_output_lr'+ learning_rate +'/'+ dataset + '/0.8/' + input_length + '/' + embedding + '/' + dim_red + '/' + optim
accuracy_path = os.path.join(path, 'Accuracy.csv')
loss_path = os.path.join(path, 'Loss.csv')

# %%
df_accuracy_raw = pd.read_csv(accuracy_path)
df_loss_raw = pd.read_csv(loss_path)

df_accuracy = df_accuracy_raw[df_accuracy_raw['Epoch']<= int(epochs)]
df_loss = df_loss_raw[df_loss_raw['Epoch']<= int(epochs)]

# %%
df_accuracy_train = df_accuracy[df_accuracy['Phase']=='Training']
df_accuracy_val = df_accuracy[df_accuracy['Phase']=='Validation']
df_loss_train = df_loss[df_loss['Phase']=='Training']
df_loss_val = df_loss[df_loss['Phase']=='Validation']

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(df_accuracy_train['Epoch'], df_accuracy_train['Accuracy'])
ax1.plot(df_accuracy_val['Epoch'], df_accuracy_val['Accuracy'])
ax1.set_title('Accuracy')
ax1.legend(['Training set', 'Validation set'])
ax1.set_xticks(np.arange(0, max(df_accuracy_train['Epoch'])+1, 5.0))
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy (%)')
ax2.plot(df_loss_train['Epoch'], df_loss_train['Loss'])
ax2.plot(df_loss_val['Epoch'], df_loss_val['Loss'])
ax2.set_xticks(np.arange(0, max(df_accuracy_train['Epoch'])+1, 5.0))
ax2.set_title('Loss')
ax2.legend(['Training set', 'Validation set'])
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
